# %%
#'总价格', '单价', '地段', '房屋户型', '所在楼层', '建筑面积', '户型结构', '装修情况'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# 加载数据集
dongcheng_df = pd.read_csv('dongcheng_after.csv', encoding='GB18030')
haidian_df = pd.read_csv('haidian_after.csv', encoding='GB18030')
huairou_df = pd.read_csv('huairou_after.csv', encoding='GB18030')
tongzhou_df = pd.read_csv('tongzhou_after.csv', encoding='GB18030')

# 合并数据并标注城区
dongcheng_df['District'] = 'Dongcheng'
haidian_df['District'] = 'Haidian'
huairou_df['District'] = 'Huairou'
tongzhou_df['District'] = 'Tongzhou'
all_data = pd.concat([dongcheng_df, haidian_df, huairou_df, tongzhou_df])

# 设置绘图风格
sns.set(style="whitegrid")

# %%
# 查看每个数据帧的属性类型
print("东城数据集属性信息:")
dongcheng_df.info()

print("\n海淀数据集属性信息:")
haidian_df.info()

print("\n怀柔数据集属性信息:")
huairou_df.info()

print("\n通州数据集属性信息:")
tongzhou_df.info()
# Out:
# 东城数据集属性信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   总价格       1030 non-null   float64
#  1   单价        1030 non-null   int64
#  2   地段        1030 non-null   object
#  3   房屋户型      1030 non-null   object
#  4   所在楼层      1030 non-null   object
#  5   建筑面积      1030 non-null   float64
#  6   户型结构      1030 non-null   object
#  7   装修情况      1030 non-null   object
#  8   District  1030 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 72.5+ KB
#
# 海淀数据集属性信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965 entries, 0 to 964
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   总价格       965 non-null    float64
#  1   单价        965 non-null    int64
#  2   地段        965 non-null    object
#  3   房屋户型      965 non-null    object
# ...

# %%
# 查看每个数据集各属性列的大体情况
print("Dongcheng 数据集各属性列的大体情况:")
print(dongcheng_df.describe())

print("\nHaidian 数据集各属性列的大体情况:")
print(haidian_df.describe())

print("\nHuairou 数据集各属性列的大体情况:")
print(huairou_df.describe())

print("\nTongzhou 数据集各属性列的大体情况:")
print(tongzhou_df.describe())
# Out:
# Dongcheng 数据集各属性列的大体情况:
#                总价格             单价         建筑面积
# count  1030.000000    1030.000000  1030.000000
# mean    940.155825  107827.816505    87.861903
# std     581.340385   21494.902405    50.957955
# min     208.000000   31172.000000    14.300000
# 25%     595.000000   94172.500000    57.522500
# 50%     755.000000  107183.500000    71.505000
# 75%    1098.500000  121022.250000   100.627500
# max    5200.000000  179834.000000   473.890000
#
# Haidian 数据集各属性列的大体情况:
#                总价格             单价        建筑面积
# count   965.000000     965.000000  965.000000
# mean    771.569016   89542.381347   84.864528
# std     491.148661   21294.243761   42.259718
# min     155.000000   30883.000000   22.040000
# 25%     480.000000   76422.000000   57.900000
# 50%     620.000000   87992.000000   71.000000
# 75%     880.000000  101984.000000   98.550000
# max    4875.000000  179930.000000  518.490000
#
# Huairou 数据集各属性列的大体情况:
#                总价格           单价        建筑面积
# ...

# %%
# 设置matplotlib的字体为支持中文的字体
matplotlib.rcParams['font.family'] = ['SimHei']  # 'SimHei' 是一个常见的中文黑体字体
matplotlib.rcParams['axes.unicode_minus'] = False  # 正确显示负号

# 总价格 - 箱线图
plt.figure(figsize=(14, 8))
sns.boxplot(x='District', y='总价格', data=all_data)
plt.title('Total Price by District')
plt.show()

# %%
# 设置matplotlib的字体为支持中文的字体
matplotlib.rcParams['font.family'] = ['SimHei']  # 'SimHei' 是一个常见的中文黑体字体
matplotlib.rcParams['axes.unicode_minus'] = False  # 正确显示负号

# 单价 - 箱线图
plt.figure(figsize=(14, 8))
sns.boxplot(x='District', y='单价', data=all_data)
plt.title('Unit Price by District')
plt.show()

# %%
# 设置matplotlib的字体为支持中文的字体
matplotlib.rcParams['font.family'] = ['SimHei']  # 'SimHei' 是一个常见的中文黑体字体
matplotlib.rcParams['axes.unicode_minus'] = False  # 正确显示负号

# 建筑面积 - 箱线图
plt.figure(figsize=(14, 8))
sns.boxplot(x='District', y='建筑面积', data=all_data)
plt.title('Construction Area by District')
plt.show()

# %%
# 设置matplotlib的字体为支持中文的字体
matplotlib.rcParams['font.family'] = ['SimHei']  # 'SimHei' 是一个常见的中文黑体字体
matplotlib.rcParams['axes.unicode_minus'] = False  # 正确显示负号


# 遍历每个区并绘制房屋户型分布饼图
districts = all_data['District'].unique()
for district in districts:
    district_data = all_data[all_data['District'] == district]
    house_type_counts = district_data['房屋户型'].value_counts()
    
    # 绘制饼图
    plt.figure(figsize=(10, 8))
    plt.pie(house_type_counts, labels=house_type_counts.index, autopct='%1.1f%%', startangle=140)
    plt.title(f'{district}房屋户型分布')
    plt.show()
    
    # 输出分布情况
    print(f'{district}房屋户型分布情况:')
    print(house_type_counts)
    print("\n")
# Out:
# Dongcheng房屋户型分布情况:
# 2室1厅1厨1卫    413
# 3室1厅1厨1卫    168
# 1室1厅1厨1卫    152
# 3室2厅1厨2卫     59
# 3室1厅1厨2卫     54
# 2室2厅1厨1卫     26
# 2室1厅1厨2卫     23
# 2室2厅1厨2卫     20
# 4室2厅1厨2卫     15
# 1室0厅1厨1卫     15
# 3室2厅1厨1卫     12
# 4室1厅1厨2卫      9
# 4室2厅1厨3卫      8
# 3室2厅1厨3卫      7
# 4室1厅1厨1卫      4
# 2室0厅1厨1卫      3
# 4室2厅1厨4卫      3
# 5室2厅1厨3卫      3
# 3室0厅1厨1卫      3
# 3室1厅1厨3卫      2
# 6室2厅1厨3卫      2
# 3室3厅1厨2卫      2
# 1室2厅1厨1卫      2
# 6室2厅1厨4卫      2
# 1室0厅0厨0卫      2
# 5室3厅2厨7卫      1
# 5室2厅1厨4卫      1
# 5室3厅1厨5卫      1
# 4室2厅1厨5卫      1
# 2室1厅2厨2卫      1
# 5室2厅1厨1卫      1
# 3室1厅1厨4卫      1
# 2室1厅2厨1卫      1
# 5室2厅1厨2卫      1
# 4室2厅1厨6卫      1
# 2室2厅2厨3卫      1
# 3室1厅2厨2卫      1
# 4室1厅2厨2卫      1
# 6室2厅1厨2卫      1
# 1室1厅1厨2卫      1
# 2室2厅1厨3卫      1
# 5室1厅1厨2卫      1
# 5室1厅1厨4卫      1
# 4室1厅1厨3卫      1
# 2房间1卫         1
# 5室3厅1厨2卫      1
# Name: 房屋户型, dtype: int64
# Haidian房屋户型分布情况:
# 2室1厅1厨1卫    451
# 3室1厅1厨1卫    148
# 1室1厅1厨1卫    124
# 3室2厅1厨2卫     83
# 3室1厅1厨2卫     37
# ...

# %%
# 设置matplotlib的字体为支持中文的字体
matplotlib.rcParams['font.family'] = ['SimHei']  # 'SimHei' 是一个常见的中文黑体字体
matplotlib.rcParams['axes.unicode_minus'] = False  # 正确显示负号

# 所在楼层 - 柱状图
plt.figure(figsize=(14, 8))
sns.countplot(x='所在楼层', hue='District', data=all_data)
plt.title('Floor Level Distribution by District')
plt.show()
for district in districts:
    district_data = all_data[all_data['District'] == district]
     
    # 输出分布情况
    print(f'{district}所在楼层分布情况:')
    print(district_data['所在楼层'].value_counts())
    print("\n")
# Out:
# Dongcheng所在楼层分布情况:
# 中楼层     402
# 高楼层     219
# 低楼层     189
# 底层      111
# 顶层      107
# 地下室       2
# Name: 所在楼层, dtype: int64
#
#
# Haidian所在楼层分布情况:
# 中楼层     389
# 低楼层     197
# 高楼层     179
# 顶层      115
# 底层       83
# 地下室       2
# Name: 所在楼层, dtype: int64
#
#
# Huairou所在楼层分布情况:
# 中楼层     321
# 顶层      226
# 底层      192
# 高楼层     154
# 低楼层     104
# 地下室       2
# Name: 所在楼层, dtype: int64
#
#
# Tongzhou所在楼层分布情况:
# 中楼层     356
# 低楼层     241
# 高楼层     229
# 底层       87
# 顶层       80
# 地下室       1
# Name: 所在楼层, dtype: int64

# %%
# 设置matplotlib的字体为支持中文的字体
matplotlib.rcParams['font.family'] = ['SimHei']  # 'SimHei' 是一个常见的中文黑体字体
matplotlib.rcParams['axes.unicode_minus'] = False  # 正确显示负号

# 户型结构 - 柱状图
plt.figure(figsize=(14, 8))
sns.countplot(x='户型结构', hue='District', data=all_data)
plt.title('House Structure Distribution by District')
plt.show()

# %%
# 设置matplotlib的字体为支持中文的字体
matplotlib.rcParams['font.family'] = ['SimHei']  # 'SimHei' 是一个常见的中文黑体字体
matplotlib.rcParams['axes.unicode_minus'] = False  # 正确显示负号

# 装修情况 - 柱状图
plt.figure(figsize=(14, 8))
sns.countplot(x='装修情况', hue='District', data=all_data)
plt.title('Decoration Type Distribution by District')
plt.show()

# %%
 #分析影响房价的主要因素有哪些，即分析房价与其他变量之间的关系

# %%
# 散点图 - 展示住房面积与总价的关系
plt.figure(figsize=(12, 6))
sns.scatterplot(x='建筑面积', y='总价格', hue='District', data=all_data)
plt.title('住房面积与总价的散点图')
plt.xlabel('建筑面积（平方米）')
plt.ylabel('总价格（万元）')
plt.legend(title='城区')
plt.show()

# 线性回归图 - 展示住房面积与总价的关系及趋势线
plt.figure(figsize=(12, 6))
sns.lmplot(x='建筑面积', y='总价格', hue='District', data=all_data, aspect=2)
plt.title('住房面积与总价的线性回归图')
plt.xlabel('建筑面积（平方米）')
plt.ylabel('总价格（万元）')
plt.show()

# %%
# 箱线图 - 展示总价与所在楼层的关系
from statistics import mean


plt.figure(figsize=(12, 6))
sns.boxplot(x='所在楼层', y='总价格', hue='District', data=all_data)
plt.title('总价与所在楼层的箱线图')
plt.xlabel('所在楼层')
plt.ylabel('总价格（万元）')
plt.legend(title='城区')
plt.show()

# 柱状图 - 展示不同楼层的平均房价
plt.figure(figsize=(12, 6))
sns.barplot(x='所在楼层', y='总价格', hue='District', data=all_data, estimator=mean)
plt.title('不同楼层的平均房价柱状图')
plt.xlabel('所在楼层')
plt.ylabel('平均总价格（万元）')
plt.legend(title='城区')
plt.show()

# %%
# 箱线图 - 展示总价与装修情况的关系
plt.figure(figsize=(12, 6))
sns.boxplot(x='装修情况', y='总价格', data=all_data)
plt.title('房价与装修情况的箱线图')
plt.xlabel('装修情况')
plt.ylabel('总价格（万元）')
plt.show()

# 柱状图 - 展示不同装修情况的平均房价
plt.figure(figsize=(12, 6))
sns.barplot(x='装修情况', y='总价格', data=all_data, estimator=mean)
plt.title('不同装修情况的平均房价柱状图')
plt.xlabel('装修情况')
plt.ylabel('平均总价格（万元）')
plt.show()

# %%
#热力图
